# %% [markdown]
# ## Aditya Choudhary

# %% [markdown]
# ## 47680288

# %% [markdown]
# # DataSet Name
# Data description paragraph
#
# ## Number of Records and Features
# ### Describe all the feature

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
# read data from csv file
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# %%
df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        150500.0     325000.0       0.4630    Commercial              NaN
# 1        253000.0     430000.0       0.5883   Residential    Single Family
# 2        130400.0     179900.0       0.7248   Residential            Condo
# 3        619290.0     890000.0       0.6958   Residential    Single Family
# 4        862330.0    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# ...

# %%
df.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')

# %%
df.shape
# Out:
# (997213, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# ...

# %%
sample_data = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# %%
print(len(sample_data))
# Out:
# 997213

# %% [markdown]
# # Q1. Check and remove missing data
# ### Q1.1 Write a Python code snippet that checks for missing values in each column of the dataset. If any, only display the names of the columns with missing values and their corresponding number of missing values. Print the length of the data before removing the missing data.

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')
# Check for missing values in each column
missing_values = df.isnull().sum()

# Filter columns with missing values
columns_with_missing_values = missing_values[missing_values > 0]

# Display column names and number of missing values
if len(columns_with_missing_values) > 0:
    print("Columns with missing values:")
    for column in columns_with_missing_values.index:
        print(f"{column}: {columns_with_missing_values[column]} missing values")
else:
    print("No missing values found in the dataset.")
# Out:
# Columns with missing values:
# Date Recorded: 2 missing values
# Address: 51 missing values
# Property Type: 382446 missing values
# Residential Type: 388309 missing values
# Non Use Code: 707532 missing values
# Assessor Remarks: 847349 missing values
# OPM remarks: 987279 missing values
# Location: 799516 missing values

# %%
df.isnull()
# Out:
#         Serial Number  List Year  Date Recorded   Town  Address  \
# 0               False      False          False  False    False
# 1               False      False          False  False    False
# 2               False      False          False  False    False
# 3               False      False          False  False    False
# 4               False      False          False  False    False
# ...               ...        ...            ...    ...      ...
# 997208          False      False          False  False    False
# 997209          False      False          False  False    False
# 997210          False      False          False  False    False
# 997211          False      False          False  False    False
# 997212          False      False          False  False    False
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 0                False        False        False          False
# 1                False        False        False          False
# ...

# %%
df.isnull().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            2
# Town                     0
# Address                 51
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type       382446
# Residential Type    388309
# Non Use Code        707532
# Assessor Remarks    847349
# OPM remarks         987279
# Location            799516
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4112484

# %%
print("length of the data before removing the missing data:",len(df))
# Out:
# length of the data before removing the missing data: 997213

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Remove rows with missing values
df_without_missing_values = df.dropna()

# Print the length of the new sample data
print("Length of the new sample data without missing values:", len(df_without_missing_values))

# Save the new sample data to a new CSV file
df_without_missing_values.to_csv('Real_Estate_Sales_NoMissing.csv', index=False)
# Out:
# Length of the new sample data without missing values: 264

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# read data from csv file
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# %%
import pandas as pd

# read the dataset into a pandas dataframe
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')
# drop any rows with missing values
df.dropna(inplace = True)

# %%
import pandas as pd

# read the dataset into a pandas dataframe
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')
# drop any rows with missing values
df.dropna(inplace = True)

# print the length of the resulting cleansed dataset
print(f"The length of the cleansed dataset is:",len(df))
# Out:
# The length of the cleansed dataset is: 264

# %%
import pandas as pd

# read the dataset into a pandas dataframe
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# print the length of the original data set
print(f"Length of data before removing missing values:", (len(df)))

# check for missing values in each column
missing_values = df.isnull().sum()

# iterate over columns with missing values and remove them
for column in df.columns:
    if missing_values[column] > 0:
        print(f"Column '{column}' has {missing_values[column]} missing values.")
        df.dropna(subset=[column], inplace=True)

# print the length of the resulting cleansed data set
print(f"Length of data after removing missing values: {len(df)}")
# Out:
# Length of data before removing missing values: 997213
# Column 'Date Recorded' has 2 missing values.
# Column 'Address' has 51 missing values.
# Column 'Property Type' has 382446 missing values.
# Column 'Residential Type' has 388309 missing values.
# Column 'Non Use Code' has 707532 missing values.
# Column 'Assessor Remarks' has 847349 missing values.
# Column 'OPM remarks' has 987279 missing values.
# Column 'Location' has 799516 missing values.
# Length of data after removing missing values: 264

# %% [markdown]
# ## Q Compute summary statistics for the columns of the sample data
# Note: the resulting output includes the count, mean, standard deviation, minimum, maximum values of the column.

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Specify the column name for which you want to compute summary statistics
column_name = 'OPM remarks'

# Compute summary statistics for the specified column
column_stats = df[column_name].describe()

# Print the summary statistics
print(column_stats)
# Out:
# count                  9934
# unique                 4825
# top       GOOD SALE PER MLS
# freq                    978
# Name: OPM remarks, dtype: object

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Specify the column name for which you want to compute summary statistics
column_name = 'Property Type'

# Compute summary statistics for the specified column
column_stats = df[column_name].describe()

# Print the summary statistics
print(column_stats)
# Out:
# count            614767
# unique               11
# top       Single Family
# freq             401612
# Name: Property Type, dtype: object

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Specify the column name for which you want to compute summary statistics
column_name = 'OPM remarks'

# Filter out non-numeric values
filtered_column = pd.to_numeric(df[column_name], errors='coerce')

# Compute summary statistics for the filtered column
count = filtered_column.count()
mean = filtered_column.mean()
std_dev = filtered_column.std()
minimum = filtered_column.min()
maximum = filtered_column.max()

# Print the summary statistics
print(f"Count: {count}")
print(f"Mean: {mean}")
print(f"Standard Deviation: {std_dev}")
print(f"Minimum: {minimum}")
print(f"Maximum: {maximum}")
# Out:
# Count: 0
# Mean: nan
# Standard Deviation: nan
# Minimum: nan
# Maximum: nan

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Compute summary statistics for all columns
summary_stats = df.describe()

# Print the summary statistics
print(summary_stats)
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   9.972130e+05  997213.000000    9.972130e+05  9.972130e+05
# mean    4.311864e+05    2010.189829    2.791437e+05  3.911512e+05
# std     6.549219e+06       6.237877    1.670610e+06  5.347270e+06
# min     0.000000e+00    2001.000000    0.000000e+00  0.000000e+00
# 25%     3.044400e+04    2004.000000    8.760000e+04  1.400000e+05
# 50%     7.030300e+04    2010.000000    1.383900e+05  2.250000e+05
# 75%     1.518780e+05    2016.000000    2.255600e+05  3.650000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  5.000000e+09
#
#         Sales Ratio
# count  9.972130e+05
# mean   1.044637e+01
# std    1.890192e+03
# min    0.000000e+00
# 25%    4.867000e-01
# 50%    6.246000e-01
# 75%    7.852761e-01
# max    1.226420e+06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Data Info
print(df.info())

# Data Description
print(df.describe())

# Handling Missing Values
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 106.5+ MB
# None
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Select the 'Property Type' column
property_type = df['Property Type']

# Create a countplot
sns.countplot(property_type)

# Set plot labels
plt.xlabel('Property Type')
plt.ylabel('Frequency')
plt.title('Frequency of Property Types')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the dataset
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Variable Identification
variables = df.columns
print("Variables:")
print(variables)

# Univariate Analysis
for variable in variables:
    if df[variable].dtype != 'object':
        # For numerical variables
        sns.histplot(df[variable])
        plt.xlabel(variable)
        plt.ylabel('Frequency')
        plt.title(f'Histogram of {variable}')
        plt.show()
    else:
        # For categorical variables
        sns.countplot(df[variable])
        plt.xlabel(variable)
        plt.ylabel('Frequency')
        plt.title(f'Countplot of {variable}')
        plt.xticks(rotation=45)
        plt.show()

# Bivariate Analysis
# Example: Relationship between 'Property Type' and 'Price'
sns.boxplot(x='Property Type', y='Price', data=df)
plt.xlabel('Property Type')
plt.ylabel('Price')
plt.title('Boxplot of Property Type vs. Price')
plt.xticks(rotation=45)
plt.show()

# Missing Value Treatment
# Count the missing values in each column
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)

# Drop rows with missing values
df_without_missing = df.dropna()

# Fill missing values with mean
# dataset_filled = dataset.fillna(dataset.mean())

# Fill missing values with mode
# dataset_filled = dataset.fillna(dataset.mode().iloc[0])

# Fill missing values with forward fill
# dataset_filled = dataset.ffill()

# Fill missing values with backward fill
# dataset_filled = dataset.bfill()

# Impute missing values using scikit-learn's SimpleImputer
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(strategy='mean')
# dataset_filled = pd.DataFrame(imputer.fit_transform(dataset), columns=dataset.columns)

# Confirm if missing values are treated
missing_values_after_treatment = df_without_missing.isnull().sum()
print("Missing Values After Treatment:")
print(missing_values_after_treatment)
# Out:
# Variables:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the sample data
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Select the 'OPM remarks' column
opm_remarks = df['OPM remarks']

# Create a histogram
sns.histplot(opm_remarks)
plt.xlabel('OPM remarks')
plt.ylabel('Frequency')
plt.title('Histogram of OPM remarks')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the sample data
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Select the 'OPM remarks' column
opm_remarks = df['OPM remarks']

# Create a boxplot
sns.boxplot(x=opm_remarks)
plt.xlabel('OPM remarks')
plt.ylabel('Value')
plt.title('Boxplot of OPM remarks')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the sample data
df = pd.read_csv('Files/Real_Estate_Sales_2001-2020_GL.csv')

# Select the 'OPM remarks' column
opm_remarks = df['Residential Type']

# Create a boxplot
sns.boxplot(x=opm_remarks)
plt.xlabel('Residential Type')
plt.ylabel('Value')
plt.title('Boxplot of Residential Type')
plt.xticks(rotation=90)
plt.show()
