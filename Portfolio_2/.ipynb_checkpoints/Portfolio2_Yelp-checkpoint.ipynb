# %% [markdown]
# ## Analysis of Yelp Dataset Portfolio2

# %% [markdown]
# The portfolio aims to use various data processing techniques to clean and preprocess the data, filter out irrelevant data, and remove any outliers that could impact the accuracy of the model. Finally, the portfolio aims to use linear regression models to train and validate the model's accuracy in predicting user ratings towards business. Ultimately, the objective is to build a reliable model that can be used to provide insights into user preferences and help businesses make data-driven decisions to improve their services and offerings. In this task, we will explore the impacts of feature selections and different sizes of training/testing data on the model performance. We will use Yelp sub-dataset.

# %% [markdown]
# ### Import the output sample data from Portfolio1
# The csv file named `Yelp_Portfolio2_Input.csv` is provided. You may need to use the Pandas method, i.e., `read_csv`, for doing this. After that, please import the csv file and print out its total length.

# %%
# Student Name
"Aditya Choudhary"
# Out:
# 'Aditya Choudhary'

# %%
# Student ID
"47680288"
# Out:
# '47680288'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score

import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
pd.read_csv('Files/Yelp_Portfolio2_Input.csv')
# Out:
#                                   business_categories business_city  \
# 0                         Middle Eastern; Restaurants         Tempe
# 1                               Tattoo; Beauty & Spas         Tempe
# 2                                   Tires; Automotive      Glendale
# 3                             Sushi Bars; Restaurants         Tempe
# 4                        Arts & Entertainment; Cinema         Tempe
# ...                                               ...           ...
# 38649                            Burgers; Restaurants      Glendale
# 38650                  Delis; Sandwiches; Restaurants         Tempe
# 38651             American (Traditional); Restaurants         Tempe
# 38652                         Gastropubs; Restaurants         Tempe
# 38653  Wine Bars; Bars; Pizza; Nightlife; Restaurants         Tempe
#
#                   business_id        date  stars  \
# 0      6oRAC4uyJCsJl1X0WZpVSA   14/6/2012      4
# ...

# %%
# read data from csv file
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
sample_data = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
print(len(sample_data))
# Out:
# 38654

# %%
sample_data.head()
# Out:
#             business_categories business_city             business_id  \
# 0   Middle Eastern; Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA
# 1         Tattoo; Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA
# 2             Tires; Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q
# 3       Sushi Bars; Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA
# 4  Arts & Entertainment; Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw
#
#          date  stars                                               text  \
# 0   14/6/2012      4  love the gyro plate. Rice is so good and I als...
# 1  23/12/2011      4  Good tattoo shop. Clean space, multiple artist...
# 2    9/9/2012      5  Never having dealt with a Discount Tire in Pho...
# 3    4/8/2010      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...
# 4  13/12/2011      4  We got passes for the preview of Mission Impos...
#
#    useful                 user_id
# 0       1  0hT2KtfLiobPvh6cDC8JQg
# 1       2  Xm8HXE1JHqscXe5BKf0GFQ
# ...

# %%
df.head()
# Out:
#             business_categories business_city             business_id  \
# 0   Middle Eastern; Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA
# 1         Tattoo; Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA
# 2             Tires; Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q
# 3       Sushi Bars; Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA
# 4  Arts & Entertainment; Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw
#
#          date  stars                                               text  \
# 0   14/6/2012      4  love the gyro plate. Rice is so good and I als...
# 1  23/12/2011      4  Good tattoo shop. Clean space, multiple artist...
# 2    9/9/2012      5  Never having dealt with a Discount Tire in Pho...
# 3    4/8/2010      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...
# 4  13/12/2011      4  We got passes for the preview of Mission Impos...
#
#    useful                 user_id
# 0       1  0hT2KtfLiobPvh6cDC8JQg
# 1       2  Xm8HXE1JHqscXe5BKf0GFQ
# ...

# %%
df.columns
# Out:
# Index(['business_categories', 'business_city', 'business_id', 'date', 'stars',
#        'text', 'useful', 'user_id'],
#       dtype='object')

# %%
df.shape
# Out:
# (38654, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                   business_categories business_city  \
# 0                         Middle Eastern; Restaurants         Tempe
# 1                               Tattoo; Beauty & Spas         Tempe
# 2                                   Tires; Automotive      Glendale
# 3                             Sushi Bars; Restaurants         Tempe
# 4                        Arts & Entertainment; Cinema         Tempe
# ...                                               ...           ...
# 38649                            Burgers; Restaurants      Glendale
# 38650                  Delis; Sandwiches; Restaurants         Tempe
# 38651             American (Traditional); Restaurants         Tempe
# 38652                         Gastropubs; Restaurants         Tempe
# 38653  Wine Bars; Bars; Pizza; Nightlife; Restaurants         Tempe
#
#                   business_id        date  stars  \
# 0      6oRAC4uyJCsJl1X0WZpVSA   14/6/2012      4
# ...

# %% [markdown]
# # Q1. `business_categories` processing

# %% [markdown]
# You may notice that there are a total of 693 unique business categories present in the sample data. Please write a code snippet to confirm this number. Then, generate a boxplot of `stars` for `business_categories`.

# %%
# your code and solutions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
# Count the number of unique business categories
num_categories = df['business_categories'].str.split('; ').explode().nunique()
print(f"Number of unique business categories: {num_categories}")
# Out:
# Number of unique business categories: 377

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# create a list of unique business categories
unique_categories = df['business_categories'].str.split('; ').explode().unique()

# generate the boxplot
plt.boxplot([df.loc[df['business_categories'].str.contains(category), 'stars'] for category in unique_categories])

# set the x-axis labels to the unique categories
plt.xticks(range(1, len(unique_categories)+1), unique_categories, rotation=90)

plt.xlabel('Business Category')
plt.ylabel('Stars')
plt.title('Distribution of Stars by Business Category')

plt.show()
# Out:
# /var/folders/gt/sfkj2f7j4wg1244sc_t5ddmm0000gn/T/ipykernel_3729/926915443.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   plt.boxplot([df.loc[df['business_categories'].str.contains(category), 'stars'] for category in unique_categories])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a pandas DataFrame
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Generate a boxplot of stars for each business category
plt.boxplot([df.loc[df['business_categories'].str.contains(category, regex=False), 'stars'] for category in df['business_categories'].str.split('; ').explode().unique()])

# Set the x-axis labels to the business categories
plt.xticks(range(1, len(df['business_categories'].str.split('; ').explode().unique()) + 1), df['business_categories'].str.split('; ').explode().unique(), rotation=90)

# Set the y-axis label to "Stars"
plt.ylabel("Stars")

# Show the plot
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Count the number of unique business categories
n_categories = df['business_categories'].str.split('; ').explode().nunique()

# Print the number of unique business categories
print(f"There are {n_categories} unique business categories in the sample data.")
# Out:
# There are 377 unique business categories in the sample data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Generate boxplot
df.boxplot(column='stars', by='business_categories')
plt.show()

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Count the number of unique business categories
num_categories = data["business_categories"].nunique()

# Print the result
print("Number of unique business categories: ", num_categories)
# Out:
# Number of unique business categories:  693

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Generate the boxplot
sns.boxplot(x="business_categories", y="stars", data=data)
# Out:
# <AxesSubplot:xlabel='business_categories', ylabel='stars'>

# %%
# Rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load sample_data
sample_data = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Get unique business_categories
unique_categories = sample_data['business_categories'].str.split('; ', expand=True).stack().unique()
num_categories = len(unique_categories)

print(f'There are {num_categories} unique business categories.')

# Boxplot of stars for business_categories
fig, ax = plt.subplots(figsize=(10, 6))
ax = sample_data.boxplot(column='stars', by='business_categories', ax=ax)
ax.set_title('')
ax.set_xlabel('Business Category')
ax.set_ylabel('Stars')
plt.xticks(rotation=90)
plt.show()
# Out:
# There are 377 unique business categories.

# %% [markdown]
# Sometimes we need to extract some major categories, such as `Middle Eastern; Restaurants` and `Sushi Bars; Restaurants`, both of which should belong to the `Restaurants` category.

# %% [markdown]
# ### Q1.1 How to efficiently and accurately extract the last category value (i.e., categorieN) from the `business_categories` column in a dataset, where the format of each row is a semicolon-separated list of categories (i.e., 'categorie1; categorie2;...;categorieN')? and replace the original string with this last category value. At last, print the first five rows.

# %%
# your code and solutions

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Extract the last category from the business_categories column and replace the original string
data['business_categories'] = data['business_categories'].str.split(';').str[-1]

# Print the first five rows of the updated DataFrame
print(data.head())
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 1  Xm8HXE1JHqscXe5BKf0GFQ
# 2  HLbhD2OyiMCUDRR4c1iXaw
# ...

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Extract the last category value from the 'business_categories' column
data['last_category'] = data['business_categories'].str.split(';').str[-1]

# Replace the original string with the last category value
data['business_categories'] = data['last_category']

# Print the first five rows to check the result
print(data.head())
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id   last_category
# 0  0hT2KtfLiobPvh6cDC8JQg     Restaurants
# ...

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Extract the last category value from the 'business_categories' column
last_category = data['business_categories'].str.split(';').str[-1]

# Print the result
print(last_category)
# Out:
# 0           Restaurants
# 1         Beauty & Spas
# 2            Automotive
# 3           Restaurants
# 4                Cinema
#               ...
# 38649       Restaurants
# 38650       Restaurants
# 38651       Restaurants
# 38652       Restaurants
# 38653       Restaurants
# Name: business_categories, Length: 38654, dtype: object

# %%
import pandas as pd

# Import the csv file
sample_data = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Print the total length of the csv file
print(len(sample_data))
# Out:
# 38654

# %%
# Define a function to extract the last category value from a string
def extract_last_category(category_string):
    categories = category_string.split(';')
    return categories[-1].strip()

# Apply the function to the business_categories column
sample_data['business_categories'] = sample_data['business_categories'].apply(extract_last_category)

# Print the first five rows
print(sample_data.head())
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 1  Xm8HXE1JHqscXe5BKf0GFQ
# 2  HLbhD2OyiMCUDRR4c1iXaw
# ...

# %%
import pandas as pd

# load the Yelp dataset into a pandas dataframe
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# create a new column called 'last_category' which stores the last category value
df['last_category'] = df['business_categories'].apply(lambda x: x.split(";")[-1].strip())

# replace the original string with the last category value
df['business_categories'] = df['last_category']

# print the first five rows
print(df.head())
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id  last_category
# 0  0hT2KtfLiobPvh6cDC8JQg    Restaurants
# ...

# %% [markdown]
# ### Q1.2 Let's first check how many unique business categories are present in the dataset (output from Q1.1). Maybe it's still not an appropriate number to make a clear Boxplot. Now, we want to display `ALL Rows` of the business category count data. That is to count and print the number of occurrences for each business category.

# %%
# your code and solutions

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Count the number of occurrences for each business category
category_counts = data['business_categories'].str.split('; ').explode().value_counts()

# Display all rows of the business category count data
pd.set_option('display.max_rows', len(category_counts))
print(category_counts)
# Out:
# Restaurants                         26400
# Food                                 6947
# Nightlife                            4934
# Bars                                 4398
# American (New)                       2767
# Shopping                             2751
# American (Traditional)               2575
# Mexican                              2574
# Pizza                                2437
# Sandwiches                           2182
# Pubs                                 2117
# Burgers                              1979
# Coffee & Tea                         1689
# Italian                              1595
# Arts & Entertainment                 1501
# Vegetarian                           1378
# Sushi Bars                           1157
# Japanese                             1132
# Thai                                 1046
# Breweries                            1037
# Event Planning & Services            1022
# Bakeries                              984
# ...

# %%
# Count the number of occurrences for each business category
category_count = sample_data['business_categories'].value_counts()

# Print the category count data
print(category_count)
# Out:
# Restaurants                   25212
# Coffee & Tea                   1116
# Shopping                       1099
# Italian                         960
# Ice Cream & Frozen Yogurt       728
#                               ...
# Internet Service Providers        3
# Meat Shops                        3
# Psychics & Astrologers            3
# Orthodontists                     3
# Doctors                           3
# Name: business_categories, Length: 182, dtype: int64

# %%
import pandas as pd

# load the Yelp dataset into a pandas dataframe
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# create a new column called 'last_category' which stores the last category value
df['last_category'] = df['business_categories'].apply(lambda x: x.split(";")[-1].strip())

# count the number of occurrences for each business category
category_counts = df['last_category'].value_counts()

# print the category counts
print(category_counts)
# Out:
# Restaurants                   25212
# Coffee & Tea                   1116
# Shopping                       1099
# Italian                         960
# Ice Cream & Frozen Yogurt       728
#                               ...
# Internet Service Providers        3
# Meat Shops                        3
# Psychics & Astrologers            3
# Orthodontists                     3
# Doctors                           3
# Name: last_category, Length: 182, dtype: int64

# %%
import pandas as pd

# load the Yelp dataset into a pandas dataframe
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# create a new column called 'last_category' which stores the last category value
df['last_category'] = df['business_categories'].apply(lambda x: x.split(";")[-1].strip())

# count the number of occurrences for each business category
category_counts = df['last_category'].value_counts()

# remove categories that appear fewer than 200 times
df = df[df['last_category'].isin(category_counts[category_counts >= 200].index)]

# %%
# print the number of resulting unique business_categories
print(len(df['last_category'].unique()))
# Out:
# 19

# %% [markdown]
# ### Q1.3 We want to remove categories that appear fewer than 200 times. Write a Python code snippet to perform this operation. At last, print the number of resulting unique business_categories.

# %%
# your code and solutions

# %%
# Print the number of resulting unique business_categories
print("Number of resulting unique business_categories:", len(data['business_categories'].str.split('; ').explode().unique()))
# Out:
# Number of resulting unique business_categories: 377

# %%
import pandas as pd
import re

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Filter the categories that appear fewer than 200 times
category_counts = data['business_categories'].str.split('; ').explode().value_counts()
valid_categories = category_counts[category_counts >= 200].index.tolist()

# Escape any special characters in the category names
valid_categories_escaped = [re.escape(cat) for cat in valid_categories]

# Filter the DataFrame to include only rows with the remaining categories
data = data[data['business_categories'].str.contains('|'.join(valid_categories_escaped))]

# Print the number of resulting unique business_categories
print("Number of resulting unique business_categories:", len(data['business_categories'].str.split('; ').explode().unique()))
# Out:
# Number of resulting unique business_categories: 357

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# Count the number of occurrences for each business category
category_counts = data['business_categories'].str.split('; ').explode().value_counts()

# Filter the categories that appear fewer than 200 times
valid_categories = category_counts[category_counts >= 200].index.tolist()

# Filter the DataFrame to include only rows with the remaining categories
data = data[data['business_categories'].str.split('; ').apply(set).apply(lambda x: set(valid_categories).issuperset(x))]

# Print the number of resulting unique business_categories
print("Number of resulting unique business_categories:", len(data['business_categories'].str.split('; ').explode().unique()))
# Out:
# Number of resulting unique business_categories: 86

# %%
# Count the number of occurrences for each business category
category_count = sample_data['business_categories'].value_counts()

# Remove categories that appear fewer than 200 times
filtered_categories = category_count[category_count >= 200].index

# Filter the sample data using the filtered categories
filtered_data = sample_data[sample_data['business_categories'].isin(filtered_categories)]

# Print the number of resulting unique business_categories
print(len(filtered_data['business_categories'].unique()))
# Out:
# 19

# %%
import pandas as pd

# load the Yelp dataset into a pandas dataframe
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# create a new column called 'last_category' which stores the last category value
df['last_category'] = df['business_categories'].apply(lambda x: x.split(";")[-1].strip())

# count the number of occurrences for each business category
category_counts = df['last_category'].value_counts()

# remove categories that appear fewer than 200 times
df = df[df['last_category'].isin(category_counts[category_counts >= 200].index)]

# print the number of resulting unique business_categories
print(len(df['last_category'].unique()))
# Out:
# 19

# %% [markdown]
# # Q2. Outliers

# %% [markdown]
# ### Q2.1 Remove any rows from the sample_data DataFrame (output from Q1.3) where the `useful` column has a value of 6 or more; Then, create a single figure with two subplots, one showing the boxplot of `useful` column of the original data and the other showing the boxplot of the data with outliers removed.
#
# At last, __print the length of the data__.

# %%
# your code and solutions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load the sample_data DataFrame from Q1.3 into a pandas dataframe
df = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# remove any rows where the useful column has a value of 6 or more
df = df[df['useful'] < 6]

# create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(15,5))

# plot the boxplot of useful column of the original data
axs[0].boxplot(df['useful'])
axs[0].set_title('Original Data')

# plot the boxplot of the data with outliers removed
axs[1].boxplot(df['useful'], showfliers=False)
axs[1].set_title('Data with Outliers Removed')

# show the figure
plt.show()

# print the length of the data
print(len(df))
# Out:
# 37505

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Remove rows where the useful column has a value of 6 or more
sample_data = sample_data.loc[sample_data['useful'] < 6]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))

# Plot the boxplot of useful column of the original data
sns.boxplot(x='useful', data=sample_data, ax=ax1)
ax1.set_title('Boxplot of Useful Column (Original Data)')

# Plot the boxplot of the data with outliers removed
sns.boxplot(x='useful', data=sample_data.loc[sample_data['useful'] < 6], ax=ax2)
ax2.set_title('Boxplot of Useful Column (Outliers Removed)')

# Show the plot
plt.show()

# %%
print("Length of sample_data after removing rows with useful >= 6:", len(sample_data))
# Out:
# Length of sample_data after removing rows with useful >= 6: 37505

# %% [markdown]
# ### Q2.2 In general, we might remove some inactive users from a dataset (output from Q2.1), for example, users who rate businesses less than 3 times. However, in this case, we are doing the opposite and removing extremely active users who rate businesses more than 30 times (>30). Again, create a single figure with two subplots, one showing the boxplot of the count of business rating given by each user and the other showing the boxplot of the data with outliers removed.
#
# At last, __print the length of the data__.

# %%
# your code and solutions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load the dataset
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
# create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

# subplot 1: boxplot of the count of business rating given by each user
ax1.boxplot(df.groupby('user_id')['business_id'].count())
ax1.set_title('Original Data')

# subplot 2: boxplot of the data with outliers removed
active_users = df['user_id'].value_counts()
active_users = active_users[active_users <= 30].index
df_filtered = df[df['user_id'].isin(active_users)]
ax2.boxplot(df_filtered.groupby('user_id')['business_id'].count())
ax2.set_title('Data with Outliers Removed')

# display the figure
plt.show()

# %%
print('Length of filtered data:', len(df_filtered))
# Out:
# Length of filtered data: 33692

# %% [markdown]
# # Q3. Training a LinearRegression model on the data output from Q2.2.

# %% [markdown]
# ### Q3.1 How to build a linear regression model on a subset of the data, using the `useful` column as the input variable and the `stars` column as the output variable. Split the data into a training set and a test set, with 70% of the data used for training. The random_state is set to 42.

# %%
# your code and solutions

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load the dataset
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
subset_df = df[['useful', 'stars']]

# %%
X_train, X_test, y_train, y_test = train_test_split(subset_df['useful'], subset_df['stars'], test_size=0.3, random_state=42)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test.values.reshape(-1, 1))

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MSE:', mse)
print('R-squared:', r2)
# Out:
# MSE: 1.5381140344690991
# R-squared: 0.0046694455176116145

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
subset = data[['useful', 'stars']]

# %%
train_set, test_set = train_test_split(subset, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(train_set[['useful']], train_set['stars'])
# Out:
# LinearRegression()

# %%
score = model.score(test_set[['useful']], test_set['stars'])
print(f'R^2 score: {score}')
# Out:
# R^2 score: 0.0046694455176116145

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load the Yelp dataset into a Pandas dataframe
yelp_data = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# Q3.1: Build a linear regression model with useful as input and stars as output
# Split the data into training and testing sets with a 70/30 split
X = yelp_data[['useful']]
y = yelp_data[['stars']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit a linear regression model on the training data
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Evaluate the model on the test data
score = lr_model.score(X_test, y_test)
print(f'R^2 score for useful vs stars regression: {score:.3f}')
# Out:
# R^2 score for useful vs stars regression: 0.005

# %% [markdown]
# ### Q3.2 Assuming that the number of reviews a business has received  `business_review_count`  can greatly influence the average rating that the business has received. Now, we create the relevant variable to the data, and do the LinearRegression again to the `stars`.

# %%
# your code and solutions

# %%
import pandas as pd

# Load the data into a pandas DataFrame
data = pd.read_csv("Files/Yelp_Portfolio2_Input.csv")

# %%
data['total_stars'] = data['stars'] * data['useful']
data['new_avg_rating'] = data['total_stars'] / data['useful']

# %%
subset = data[['useful', 'new_avg_rating']]
train_set, test_set = train_test_split(subset, test_size=0.3, random_state=42)

# %%
train_set.isnull().sum() # check for null values in the train set
train_set = train_set.fillna(train_set.mean()) # fill in missing values with the mean of the column

# %%
model = LinearRegression()
model.fit(train_set[['useful']], train_set['new_avg_rating'])
# Out:
# LinearRegression()

# %%
print(test_set.isna().sum())
# Out:
# useful               0
# new_avg_rating    5059
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# load the data into a Pandas DataFrame
df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# extract the relevant columns
X = df['useful'].values.reshape(-1, 1)
y = df['stars'].values.reshape(-1, 1)

# split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# build a linear regression model on the training data
model = LinearRegression()
model.fit(X_train, y_train)

# evaluate the model on the test data
score = model.score(X_test, y_test)
print(f'R^2 score: {score:.3f}')
# Out:
# R^2 score: 0.005

# %%
# Q3.2: Create a new variable business_review_count and perform regression on it along with useful
yelp_data['business_review_count'] = yelp_data.groupby('business_id')['business_id'].transform('count')
X = yelp_data[['useful', 'business_review_count']]
y = yelp_data[['stars']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit a linear regression model on the training data
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Evaluate the model on the test data
score = lr_model.score(X_test, y_test)
print(f'R^2 score for useful and business_review_count vs stars regression: {score:.3f}')
# Out:
# R^2 score for useful and business_review_count vs stars regression: 0.023

# %% [markdown]
# ### Q3.3 Output the correlations between `business_review_count` and `useful` variables with `stars` and analyze the results.

# %%
# your code and solutions

# %%
import pandas as pd

yelp_df = pd.read_csv('Files/Yelp_Portfolio2_Input.csv')

# %%
corr_matrix = yelp_data[['business_review_count', 'useful', 'stars']].corr()
print(corr_matrix)
# Out:
#                        business_review_count    useful     stars
# business_review_count               1.000000  0.013699  0.135448
# useful                              0.013699  1.000000 -0.063901
# stars                               0.135448 -0.063901  1.000000
